# %% [markdown]
# <a href="https://colab.research.google.com/github/RudiksChess/ClubDeAjedrezUVG/blob/main/ClubDeAjedrezResultados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
"""La base de datos de personas registradas"""

#Los datos deben estar ordenados por fecha más reciente de forma descendente 
#Único dato variable
DB = pd.read_csv('/content/AJEDREZ UVG - Registro-6.csv')
#Selecciona las columnas requeridas 
DB_columns= DB.loc[0:len(DB),["¿Nombre y apellido?","¿Carrera? ","Usuario"]]
#Elimina a las personas que no tienen usuarios
DB_columns= DB_columns[DB_columns['Usuario'].notna()]
#Convierte la columna de usuario a minúsculas
DB_columns["Usuario"]= DB_columns["Usuario"].str.lower()
#Se limpian los usuarios duplicados y se mantiene el dato más reciente.
DB_limpia = DB_columns.drop_duplicates(subset=['Usuario'])
DB_limpia.columns = ['Nombre', "Carrera", "Usuario"]
DB = DB_limpia

# %%
"""Función para ordenadar los datos de chess.com"""
def Ronda_limpia(path, ronda): 
  Ronda_chess = pd.read_csv(path)
  Ronda= Ronda_chess.loc[0:len(Ronda_chess), ["Username","Score","SB"]]
  #Convierte la columna de usuario a minúsculas
  Ronda["Username"]= Ronda["Username"].str.lower()
  #Reemplaza la anterior columna de usuarios a la nueva
  Ronda_final = Ronda.assign(Username= Ronda["Username"])
  Ronda_final.columns = ['Usuario', 'R'+str(ronda), 'D'+str(ronda)]
  return Ronda_final

#Se puede a consultar a más detalle el uso de "outer" y "left" en https://stackoverflow.com/questions/53645882/pandas-merging-101

def Juntar_Rondas_con_DB(rondas):
  return pd.merge(DB, rondas, on="Usuario", how= "right")

def Rondas_Individuales(rondaR,rondaL):
  return pd.merge(Ronda1,Ronda2, on="Usuario", how="outer")

# %%
Ronda1= Ronda_limpia("/content/AJEDREZ UVG - Liga_2_Ronda_1.csv",1)
#Ronda2 = Ronda_limpia("/content/AJEDREZ UVG - Registro-6.csv",2)
#Ronda3= Ronda_limpia(" ",3)
#Ronda4= Ronda_limpia(" ",4)

# %%
#Ronda1 
Resultado_final = Juntar_Rondas_con_DB(Ronda1)
Rondas = Resultado_final["R1"]
Desempate = Resultado_final["D1"]
Resultado_final ["Score"] = Rondas
Resultado_final ["D"] = Desempate
Resultado_final.sort_values(["D","Score"])


Resultado_final.head(30)
# Out:
#                                    Nombre  ...      D
# 0            Carlos Andrés Escobar Méndez  ...  23.50
# 1                            José Sánchez  ...  19.50
# 2                      Joan Munés Alpirez  ...  17.00
# 3   Armando Rodrigo Eliú Chocojay Chacach  ...  14.25
# 4                             André Arauz  ...  16.00
# 5                         Cayetano Molina  ...  15.00
# 6                          Baptiste Bauer  ...  14.00
# 7                             Oscar Godoy  ...  13.00
# 8                          Ernesto Chavez  ...  11.00
# 9                Andrea Barrientos Pineda  ...  10.00
# 10                 José Ignacio Gutiérrez  ...   9.25
# 11                      Guillermo Furlan   ...   6.50
# 12         José Javier Hurtarte Hernández  ...   6.50
# 13                           Juan Galicia  ...   6.00
# 14                        Kevin González   ...   5.50
# 15                          Diego Terraza  ...   4.00
# 16          Carlos Daniel Estrada Ramirez  ...   5.00
# 17                        Gaspar Santiago  ...   4.00
# 18                        Mariana Obregón  ...   2.00
# 19                      Elizabeth Bennett  ...   0.00
# 20           Rodrigo Amenábar Valladares   ...   0.00
# 21           Juan Diego Fajardo Hernández  ...   1.50
#
# [22 rows x 7 columns]

# %%
"""
#Ronda2
resultado_parcial_1_y_2= Rondas_Individuales(Ronda1,Ronda2)
resultado_final_1_y_2 = Juntar_Rondas_con_DB(resultado_parcial_1_y_2)

#Ronda3 
resultado_parcial_1_2_y_3= Rondas_Individuales(resultado_parcial_1_y_2,Ronda3)
resultado_final = Juntar_Rondas_con_DB(resultado_parcial_1_2_y_3)

#Ronda4 

resultado_parcial_1_2_3_y_4= Rondas_Individuales(resultado_parcial_1_2_y_3,Ronda4)
resultado_final = Juntar_Rondas_con_DB(resultado_parcial_1_2_3_y_4)
"""

# %%
html = Resultado_final.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre</th>
#       <th>Carrera</th>
#       <th>Usuario</th>
#       <th>R1</th>
#       <th>D1</th>
#       <th>Score</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Carlos Andrés Escobar Méndez</td>
#       <td>Ingeniería Mecatrónica</td>
#       <td>escocar06</td>
#       <td>6.0</td>
#       <td>23.50</td>
#       <td>6.0</td>
#       <td>23.50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>José Sánchez</td>
#       <td>Ingeniería Civil</td>
#       <td>civilbeast</td>
#       <td>5.0</td>
#       <td>19.50</td>
#       <td>5.0</td>
#       <td>19.50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Joan Munés Alpirez</td>
#       <td>Ingeniería en Ciencias de la Administración</td>
#       <td>joan_m7</td>
#       <td>5.0</td>
#       <td>17.00</td>
#       <td>5.0</td>
#       <td>17.00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Armando Rodrigo Eliú Chocojay Chacach</td>
#       <td>Educación</td>
#       <td>eliu_chocojay</td>
#       <td>4.5</td>
#       <td>14.25</td>
#       <td>4.5</td>
#       <td>14.25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>André Arauz</td>
#       <td>Ingeniería Mecánica Industrial</td>
#       <td>arauzandre</td>
#       <td>4.0</td>
#       <td>16.00</td>
#       <td>4.0</td>
#       <td>16.00</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Cayetano Molina</td>
#       <td>Ingeniería en Ciencias de la Computación y TI</td>
#       <td>cayomol01</td>
#       <td>4.0</td>
#       <td>15.00</td>
#       <td>4.0</td>
#       <td>15.00</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Baptiste Bauer</td>
#       <td>Licenciatura en Física</td>
#       <td>bapt1999</td>
#       <td>4.0</td>
#       <td>14.00</td>
#       <td>4.0</td>
#       <td>14.00</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Oscar Godoy</td>
#       <td>Matemática Aplicada</td>
#       <td>oscarxdxdxd169</td>
#       <td>4.0</td>
#       <td>13.00</td>
#       <td>4.0</td>
#       <td>13.00</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>